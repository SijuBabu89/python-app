# %%
# !pip install -U spacy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 37.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-sci-lg 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.6.1 which is incompatible.
# en-core-sci-md 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.6.1 which is incompatible.
# en-core-sci-sm 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.6.1 which is incompatible.
# en-ner-bc5cdr-md 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.6.1 which is incompatible.
# en-ner-bionlp13cg-md 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.6.1 which is incompatible.
# ...

# %%
# !pip install scispacy
# Out:
# ...
#   Using cached spacy-3.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.4.4 which is incompatible.
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_lg-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_lg-0.5.1.tar.gz (532.3 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bionlp13cg_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bionlp13cg_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_craft_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_craft_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_jnlpba_md-0.5.1.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_jnlpba_md-0.5.1.tar.gz (120.2 MB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install render

# %%
import scispacy
import spacy
#Core models
import en_core_sci_sm
import en_core_sci_md
import en_core_sci_lg
#NER specific models
import en_ner_bc5cdr_md
import en_ner_bionlp13cg_md
import en_ner_craft_md
import en_ner_jnlpba_md
#Tools for extracting & displaying data
from spacy import displacy
import pandas as pd

# %%
import pandas as pd
mtsample_df=pd.read_csv("files/mtsamples.csv")

print(mtsample_df.shape)
print(mtsample_df.info())

print(mtsample_df.head(2))
# Out:
# (4999, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4999 non-null   int64
#  1   description        4999 non-null   object
#  2   medical_specialty  4999 non-null   object
#  3   sample_name        4999 non-null   object
#  4   transcription      4966 non-null   object
#  5   keywords           3931 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB
# None
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
#
#        medical_specialty                                sample_name  \
# 0   Allergy / Immunology                         Allergic Rhinitis
# 1             Bariatrics   Laparoscopic Gastric Bypass Consult - 2
#
# ...

# %%
# Pick specific transcription to use (row 3, column "transcription") and test the scispacy NER model
text = mtsample_df.loc[7, "transcription"]

# %%
text1 = """This 23-year-old white female presents with complaint of allergies.  She used to have allergies when she lived in Seattle but she thinks they are worse here.  In the past, she has tried Claritin, and Zyrtec.  Both worked for short time but then seemed to lose effectiveness.  She has used Allegra also.  She used that last summer and she began using it again two weeks ago.  It does not appear to be working very well.  She has used over-the-counter sprays but no prescription nasal sprays.  She does have asthma but doest not require daily medication for this and does not think it is flaring up.,MEDICATIONS: , Her only medication currently is Ortho Tri-Cyclen and the Allegra.,ALLERGIES: , She has no known medicine allergies.,OBJECTIVE:,Vitals:  Weight was 130 pounds and blood pressure 124/78.,H
Capsule Delayed Release TAKE 1 CAPSULE BY MOUTH EVERY DAY 30 MINUTES BEFORE BREAKFAST , Not-
Taking/PRN Lansoprazole 30 MG Capsule Delayed Release 1 capsule Orally Twice a Day one hour before breakfast
and one hour before dinner , Not- Taking/PRN Dexlansoprazole 60 MG Capsule Delayed Release 1 capsule Orally
Once a day one hour before breakfast , Not- Taking/PRN Metoclopramide HCl 10 MG Tablet 1 tablet Orally Twice a
day one hour before dinner and at bedtime , Not- Taking/PRN Procardia XL 60 MG Tablet Extended Release Orally
, Not- Taking/PRN Glucotrol XL 5 MG Tablet Extended Release 1 tablet with food Orally Once a day , Not-
Taking/PRN Milk of Magnesia 400 MG/5ML Suspension 45 ml Orally at bedtime , Not- Taking/PRN Lansoprazole 30
MG Capsule Delayed Release 1 capsule Orally bid one hour before breakfast and dinner , Medication List
reviewed and reconciled with the patient"""

nlp_bc = en_ner_bc5cdr_md.load()
doc = nlp_bc(text2)
print(doc.ents)
for ent in doc.ents:
  print(ent.ent)
#Display resulting entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# (dyspepsia, esophageal ulcer, ulcer, hemorrhoids, LA, esophagitis, ulcers, gastroparesis, gastritis, Chills, pain, Chest pain, Shortness of breath, Shortness of breath, Chest pain, Chest pain, Dizziness, Dyspnea, Palpitations, Abdominal pain, Constipation, Diarrhea, Heartburn, Hematemesis, Nausea, bleeding, Vomiting, Weight loss, bruising, Denies Leg cramps, Muscle aches, Dizziness, Diabetic, stomach cancer, Cancer, prostate
# cancer, Cancer, Losartan, HCl, Metoprolol Succinate, Metoclopramide HCl, Omeprazole, Lansoprazole, Taking/PRN Dexlansoprazole, Taking/PRN Metoclopramide HCl, Taking/PRN Procardia, Taking/PRN Glucotrol, Taking/PRN Milk, Magnesia 400, Taking/PRN Lansoprazole)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Subjective:</br>Chief Complaints:</br>1. *K29.60.</br>HPI:</br> New Symptom : </br>     59 y/o male patient with h/o
# ...

# %%
nlp_bc = en_ner_bionlp13cg_md.load()
doc = nlp_bc(text1)
#Display resulting entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This 23-year-old white female presents with complaint of allergies.  She used to have allergies when she lived in Seattle but she thinks they are worse here.  In the past, she has tried
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Claritin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zyrtec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# ...

# %%
nlp_bc = en_ner_craft_md.load()
doc = nlp_bc(text1)
#Display resulting entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:206: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# ...

# %%
nlp_bc = en_ner_jnlpba_md.load()
doc = nlp_bc(text1)
#Display resulting entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:206: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
MG Capsule Delayed Release 1 capsule Orally bid one hour before breakfast and dinner , Medication List
reviewed and reconciled with the patient'''

# %%
cleansed_note = ''
if 'ROS:' in medical_note:
  parts1 = medical_note.split("ROS:")
  cleansed_note = cleansed_note + parts1[0]
  if 'Medical History:' in medical_note:
    parts2 = medical_note.split("Medical History:")
    cleansed_note = cleansed_note + "Medical History: "+parts2[1]
else:
  cleansed_note = medical_note
# Out:
# False
# Subjective:
# Chief Complaints:
# 1. *K29.60.
# HPI:
#  New Symptom :
#      59 y/o male patient with h/o dyspepsia, esophageal ulcer, and overweight is here for a follow up after a
# colonoscopy/EGD. Colonoscopy show examined portion of the ileum was normal, a single colonic ulcer in the
# cecum, erythematous mucosa in the rectum, and internal hemorrhoids. Advise patient to repeat colonoscop y
# based on pathology for surveillance. EGD show LA grade C esophagitis, esophageal ulcers, gastroparesis,
# gastritis, and a normal duodenum. Path report show no significant histopathology on esophagus or stomach.
# Patient advised to repeat EGD in 3 months to check for healing and for surveillance. Results discussed with
# patient. Significance of findings and importance of surveillance explained to patient. Anti reflux measures
# including increase physical activity explained to patient. All patient questions were answered. Patient understand
# and agrees to plan.
# ROSO:
# ...

# %%
nlp_bc5cdr = en_ner_bc5cdr_md.load()

# %%
nlp_sm = en_core_sci_sm.load()
doc_sm = nlp_sm(medical_note)
str_sm = ""
entities = doc_sm.ents
for ent in entities:
  str_sm = str_sm +' ' +f'\n'+ent.text
# Filter entities to keep only disease entities
print('----------------------------------------')
disease_entities_sm = ""
#9255184837977538312
#9255184837977538312
disease_sm = nlp_bc5cdr(str_sm)
for entity in disease_sm.ents:
  if 9255184837977538312 == entity.label:
    disease_entities_sm = disease_entities_sm +' ' +f'\n'+entity.text
print(disease_entities_sm)
print('##############################################################################################')
# Out:
# ----------------------------------------
#
# dyspepsia
# esophageal ulcer
# ulcer
# hemorrhoids
# esophagitis
# ulcers
# gastroparesis
# Shortness of breath
# Chest pain
# Chest pain
# Palpitations
# Abdominal pain
# Decreased appetite
# Nausea
# Leg cramps
# Diabetic
# stomach cancer
# Cancer
# prostate
# cancer
# Cancer
# ##############################################################################################

# %%
nlp_md = en_core_sci_md.load()
doc_md = nlp_sm(medical_note)
str_md = ""
entities = doc_md.ents
for ent in entities:
  str_md = str_md +' ' +f'\n'+ent.text

disease_entities_md = ''
disease_md = nlp_bc5cdr(str_md)
for entity in disease_md.ents:
  if 9255184837977538312 == entity.label:
    disease_entities_md = disease_entities_md +' ' +f'\n'+entity.text
print(disease_entities_sm)
#displacy_image = displacy.render(disease_md, jupyter=True,style='ent')
print('##############################################################################################')
# Out:
#
# dyspepsia
# esophageal ulcer
# ulcer
# hemorrhoids
# esophagitis
# ulcers
# gastroparesis
# Shortness of breath
# Chest pain
# Chest pain
# Palpitations
# Abdominal pain
# Decreased appetite
# Nausea
# Leg cramps
# Diabetic
# stomach cancer
# Cancer
# prostate
# cancer
# Cancer
# ##############################################################################################

# %%
nlp_lg = en_core_sci_lg.load()
doc_lg = nlp_sm(medical_note)
str_lg = ""
entities = doc_lg.ents
for ent in entities:
  str_lg = str_lg +' ' +f'\n'+ent.text

disease_entities_lg = ''
disease_lg = nlp_bc5cdr(str_lg)
for entity in disease_lg.ents:
  if 9255184837977538312 == entity.label:
    disease_entities_lg = disease_entities_lg +' ' +f'\n'+entity.text
print(disease_entities_lg)
#displacy_image = displacy.render(disease_lg, jupyter=True,style='ent')
print('##############################################################################################')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-941bfac3c5be> in <cell line: 1>()
# ----> 1 nlp_lg = en_core_sci_lg.load()
#       2 doc_lg = nlp_sm(medical_note)
#       3 str_lg = ""
#       4 entities = doc_lg.ents
#       5 for ent in entities:
#
# NameError: name 'en_core_sci_lg' is not defined

# %%
nlp_sm = en_core_sci_md.load()
text1 = """This 23-year-old white female presents with complaint of allergies.  She used to have allergies when she lived in Seattle but she thinks they are worse here.  In the past, she has tried Claritin, and Zyrtec.  Both worked for short time but then seemed to lose effectiveness.  She has used Allegra also.  She used that last summer and she began using it again two weeks ago.  It does not appear to be working very well.  She has used over-the-counter sprays but no prescription nasal sprays.  She does have asthma but doest not require daily medication for this and does not think it is flaring up.,MEDICATIONS: , Her only medication currently is Ortho Tri-Cyclen and the Allegra.,ALLERGIES: , She has no known medicine allergies.,OBJECTIVE:,Vitals:  Weight was 130 pounds and blood pressure 124/78.,HEENT:  Her throat was mildly erythematous without exudate.  Nasal mucosa was erythematous and swollen.  Only clear drainage was seen.  TMs were clear.,Neck:  Supple without adenopathy.,Lungs:  Clear.,ASSESSMENT:,  Allergic rhinitis.,PLAN:,1.  She will try Zyrtec instead of Allegra again.  Another option will be to use loratadine.  She does not think she has prescription coverage so that might be cheaper.,2.  Samples of Nasonex two sprays in each nostril given for three weeks.  A prescription was written as well."""
doc = nlp_sm(text1)
#Display resulting
#entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This 23-year-old
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     white
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     female
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  presents with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     complaint
# ...

# %%
nlp_sm = en_core_sci_lg.load()
text1 = """This 23-year-old white female presents with complaint of allergies.  She used to have allergies when she lived in Seattle but she thinks they are worse here.  In the past, she has tried Claritin, and Zyrtec.  Both worked for short time but then seemed to lose effectiveness.  She has used Allegra also.  She used that last summer and she began using it again two weeks ago.  It does not appear to be working very well.  She has used over-the-counter sprays but no prescription nasal sprays.  She does have asthma but doest not require daily medication for this and does not think it is flaring up.,MEDICATIONS: , Her only medication currently is Ortho Tri-Cyclen and the Allegra.,ALLERGIES: , She has no known medicine allergies.,OBJECTIVE:,Vitals:  Weight was 130 pounds and blood pressure 124/78.,HEENT:  Her throat was mildly erythematous without exudate.  Nasal mucosa was erythematous and swollen.  Only clear drainage was seen.  TMs were clear.,Neck:  Supple without adenopathy.,Lungs:  Clear.,ASSESSMENT:,  Allergic rhinitis.,PLAN:,1.  She will try Zyrtec instead of Allegra again.  Another option will be to use loratadine.  She does not think she has prescription coverage so that might be cheaper.,2.  Samples of Nasonex two sprays in each nostril given for three weeks.  A prescription was written as well."""
doc = nlp_sm(text1)
#Display resulting
#entity extraction
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This 23-year-old
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     white
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     female
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  presents with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     complaint
# ...
